# %%
import sys, time
import ray
from ray.tune import experiment
from ray.air import CheckpointConfig, RunConfig, session

from fran.managers.raytune_manager import *
from fran.utils.helpers import *

from skimage._shared.utils import check_nD
sys.path+= [".."]
import os; 
tr2 = ray.util.pdb.set_trace
# Out:
# Please cite the following paper when using nnUNet:
#
# Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
#
#
# If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
#
# https://app.neptune.ai/drusmanbashir/KiTS19/
# Remember to stop your project once you’ve finished logging your metadata (https://docs.neptune.ai/api/project#stop). It will be stopped automatically only when the notebook kernel/interactive console is terminated.

# %%
# For myself. Delete this cell if you want
if is_notebook() == False:
    os.chdir("nbs")

# %%
common_paths_filename="config.yaml"
proj_defaults = load_proj_defaults(common_paths_filename,"kits21")
config_dict =  load_config_from_workbook(proj_defaults.configuration_filename, raytune=False)

# %% [markdown]
# # If you are new to ray-tune, please see their [Getting started](https://docs.ray.io/en/latest/tune/getting-started.html) page.
# # Ray-tune options are set below. Alter them to your preference.

# %%
os.environ['TUNE_DISABLE_STRICT_METRIC_CHECKING']="1"
n_trials=5
raytune=True
profiler=False
n_gpu_per_trial=1
n_cpu_per_trial =32/n_gpu_per_trial    # alter this based on your number of cpu cores
    #Note: Make sure you have set the CUDA_VISIBLE_DEVICES env variable otherwise ray will not recognize your GPU.
neptune=True  # enables neptune logging.
max_epochs = 2
grace_period=1
if profiler==True:  
    os.environ["PERFTOOLS_PATH"]="/usr/lib/x86_64-linux-gnu/libprofiler.so"
    os.environ["PERFTOOLS_LOGFILE"]="/tmp/pprof.out"

config = load_config_from_workbook(proj_defaults.configuration_filename, raytune=raytune)
metadata =config['metadata']
dice_channel = 1 if out_channels_from_dict_or_cell(metadata['dest_labels'])==2 else 2
monitor = "loss_dice_region"+str(dice_channel)
# most_recent_experiment= metadata['most_recent_experiment'].item()

resume= False
most_recent_experiment="kits21_337"
if resume==True:
    experiment_name=most_recent_experiment
else:
    experiment_name=proj_defaults.project_title +"_"+ str(random.randint(1,1e+3)) 

debug_mode = False
if debug_mode ==True:
    ray.init(local_mode=True)
num_samples = 4 if debug_mode==True else n_trials
max_num_epochs = 3 if debug_mode==True else max_epochs
grace_period = max_num_epochs if debug_mode == True else grace_period
scheduler = ASHAScheduler(
    metric=monitor,
    mode="min",
    max_t=max_num_epochs,
    grace_period=grace_period,
    reduction_factor=2)
    


loss_channels = out_channels_from_dict_or_cell(metadata['dest_labels'])
loss_cols = ["loss_dice_label"+str(indx) for indx in range(1,loss_channels)]
# loss_cols = ["loss_dice_label1"]
loss_cols = ["training_iteration", "loss_ce_focal"] + loss_cols
reporter = CLIReporter(
    metric_columns=loss_cols ,
    parameter_columns = {'dataset_params/stride_random': 'random stride'},
)

# %%
train_single_gpu= partial(train_with_tune,False,neptune,max_num_epochs,proj_defaults)
train_multi_gpu= partial(train_with_tune,True, neptune,raytune,max_num_epochs,proj_defaults)
train = train_multi_gpu if n_gpu_per_trial>1 else train_single_gpu

# %% [markdown]
# # Setting up Ray Tuners: One for new trials. Another to resume previous trial (name stored manually as most_recent_experiment)

# %%
trial_path = proj_defaults.checkpoints_parent_folder/experiment_name
trainable_with_resources = tune.with_resources(train, {"cpu": 24, "gpu":1})
tuner_new = tune.Tuner(
    trainable_with_resources,
    tune_config=tune.TuneConfig(
        num_samples = num_samples,
        scheduler = scheduler,
        trial_name_creator=lambda trial: trial_str_creator(experiment_name), # this ignore trial name!
        trial_dirname_creator = trial_dirname_creator,
    ),
    param_space = config,
    run_config = RunConfig(
        name=experiment_name,

        local_dir = proj_defaults.checkpoints_parent_folder,
        checkpoint_config= CheckpointConfig(

        num_to_keep=5,
        checkpoint_at_end=False,
        ),
        progress_reporter=reporter
        
    ),

            

)

tuner_resume = tune.Tuner.restore(
    path=str(trial_path)

)

# %% [markdown]
# # Running the Ray Tune experiment. Note down the experiment name for reference. It is also stored under the corresponding online Neptune run as metadata/run_name

# %%
if resume==True:
    print("Resuming existing experiment, name: {}".format(experiment_name))
    results = tuner_resume.fit()
else:
    results = tuner_new.fit()

#
# Out:
# 2023-01-17 18:22:47,790	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265
# (pid=563285)
# (pid=563285)
# (pid=563285) Please cite the following paper when using nnUNet:
# (pid=563285)
# (pid=563285) Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
# (pid=563285)
# (pid=563285)
# (pid=563285) If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
# (pid=563285)
# == Status ==
# Current time: 2023-01-17 18:22:49 (running for 00:00:00.17)
# Memory usage on this node: 13.9/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 24.0/48 CPUs, 1.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (4 PENDING, 1 RUNNING)
# +----------------+----------+---------------------+-----------------+
# | Trial name     | status   | loc                 | random stride   |
# |----------------+----------+---------------------+-----------------|
# | kits21_162_327 | RUNNING  | 192.168.0.63:563285 | False           |
# | kits21_162_329 | PENDING  |                     | False           |
# | kits21_162_331 | PENDING  |                     | True            |
# | kits21_162_333 | PENDING  |                     | True            |
# | kits21_162_335 | PENDING  |                     | True            |
# +----------------+----------+---------------------+-----------------+
#
#
# (pid=563285) https://app.neptune.ai/drusmanbashir/KiTS19/
# (func pid=563285) Loading dataset from BBox file /home/ub/datasets/preprocessed/kits21/stage2_patches/64_160_160/bboxes_info
# (func pid=563285) Loading dataset from BBox file /home/ub/datasets/preprocessed/kits21/stage2_patches/64_160_160/bboxes_info
# (func pid=563285) https://app.neptune.ai/drusmanbashir/KiTS19/
# (func pid=563285) No checkpoints on Tune. Initializing..
# (pid=563461)
# (pid=563461)
# (pid=563461) Please cite the following paper when using nnUNet:
# (pid=563461)
# (pid=563461) Isensee, F., Jaeger, P.F., Kohl, S.A.A. et al. "nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation." Nat Methods (2020). https://doi.org/10.1038/s41592-020-01008-z
# (pid=563461)
# (pid=563461)
# (pid=563461) If you have questions or suggestions, feel free to open an issue at https://github.com/MIC-DKFZ/nnUNet
# (pid=563461)
# (func pid=563285) /home/ub/Dropbox/code/fran/fran/utils/callbacks.py:145: NeptuneDeprecationWarning: Parameter `run` is deprecated, use `with_id` instead. We'll end support of it in `neptune-client==1.0.0`.
# (func pid=563285)   nep_run = neptune.init_run(run=None,mode="async",**self.neptune_run_settings)
# (pid=563461) https://app.neptune.ai/drusmanbashir/KiTS19/
# (func pid=563461) Loading dataset from BBox file /home/ub/datasets/preprocessed/kits21/stage2_patches/64_160_160/bboxes_info
# (func pid=563461) Loading dataset from BBox file /home/ub/datasets/preprocessed/kits21/stage2_patches/64_160_160/bboxes_info
# (func pid=563461) https://app.neptune.ai/drusmanbashir/KiTS19/
# (func pid=563285) https://app.neptune.ai/drusmanbashir/KiTS19/e/KITS-2387
# (func pid=563285) /home/ub/programs/miniconda3/envs/ai/lib/python3.10/site-packages/neptune/new/attributes/attribute.py:64: NeptuneDeprecationWarning: The object you're logging will be implicitly cast to a string. We'll end support of this behavior in `neptune-client==1.0.0`. To log the object as a string, use `str(object)` instead.
# (func pid=563285)   return self.assign(value, wait)
# (func pid=563461) No checkpoints on Tune. Initializing..
# (func pid=563285) Initializing new run. Run name kits21_162_327
# == Status ==
# Current time: 2023-01-17 18:22:58 (running for 00:00:09.24)
# Memory usage on this node: 15.4/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 48.0/48 CPUs, 2.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (3 PENDING, 2 RUNNING)
# +----------------+----------+---------------------+-----------------+
# | Trial name     | status   | loc                 | random stride   |
# |----------------+----------+---------------------+-----------------|
# | kits21_162_327 | RUNNING  | 192.168.0.63:563285 | False           |
# | kits21_162_329 | RUNNING  | 192.168.0.63:563461 | False           |
# | kits21_162_331 | PENDING  |                     | True            |
# | kits21_162_333 | PENDING  |                     | True            |
# | kits21_162_335 | PENDING  |                     | True            |
# +----------------+----------+---------------------+-----------------+
#
#
# (func pid=563285) Making folder /s/checkpoints/kits21/kits21_162/kits21_162_327/model_checkpoints
# epoch     train_loss  valid_loss  time
# Epoch 1/2 : |----------------------------------------| 0.00% [0/54 00:00<?]
# (func pid=563461) /home/ub/Dropbox/code/fran/fran/utils/callbacks.py:145: NeptuneDeprecationWarning: Parameter `run` is deprecated, use `with_id` instead. We'll end support of it in `neptune-client==1.0.0`.
# (func pid=563461)   nep_run = neptune.init_run(run=None,mode="async",**self.neptune_run_settings)
# (func pid=563461) https://app.neptune.ai/drusmanbashir/KiTS19/e/KITS-2388
# Epoch 1/2 : |----------------------------------------| 1.85% [1/54 00:00<00:28]
# (func pid=563461) /home/ub/programs/miniconda3/envs/ai/lib/python3.10/site-packages/neptune/new/attributes/attribute.py:64: NeptuneDeprecationWarning: The object you're logging will be implicitly cast to a string. We'll end support of this behavior in `neptune-client==1.0.0`. To log the object as a string, use `str(object)` instead.
# (func pid=563461)   return self.assign(value, wait)
# Epoch 1/2 : |█---------------------------------------| 3.70% [2/54 00:00<00:24 0.7411]
# (func pid=563461) Initializing new run. Run name kits21_162_329
# Epoch 1/2 : |██--------------------------------------| 5.56% [3/54 00:01<00:22 0.7399]
# Epoch 1/2 : |██--------------------------------------| 7.41% [4/54 00:01<00:21 0.6732]
# Epoch 1/2 : |███-------------------------------------| 9.26% [5/54 00:02<00:22 0.6218]
# == Status ==
# Current time: 2023-01-17 18:23:03 (running for 00:00:14.24)
# Memory usage on this node: 20.2/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 48.0/48 CPUs, 2.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (3 PENDING, 2 RUNNING)
# +----------------+----------+---------------------+-----------------+
# | Trial name     | status   | loc                 | random stride   |
# |----------------+----------+---------------------+-----------------|
# | kits21_162_327 | RUNNING  | 192.168.0.63:563285 | False           |
# | kits21_162_329 | RUNNING  | 192.168.0.63:563461 | False           |
# | kits21_162_331 | PENDING  |                     | True            |
# | kits21_162_333 | PENDING  |                     | True            |
# | kits21_162_335 | PENDING  |                     | True            |
# +----------------+----------+---------------------+-----------------+
#
#
# Epoch 1/2 : |████------------------------------------| 11.11% [6/54 00:02<00:21 0.6056]
# Epoch 1/2 : |█████-----------------------------------| 12.96% [7/54 00:03<00:25 0.5559]
# (func pid=563461) Making folder /s/checkpoints/kits21/kits21_162/kits21_162_329/model_checkpoints
# epoch     train_loss  valid_loss  time
# Epoch 1/2 : |----------------------------------------| 0.00% [0/54 00:00<?]
# Epoch 1/2 : |█████-----------------------------------| 14.81% [8/54 00:04<00:27 0.5271]
# Epoch 1/2 : |----------------------------------------| 1.85% [1/54 00:00<00:52]
# Epoch 1/2 : |██████----------------------------------| 16.67% [9/54 00:05<00:25 0.5076]
# Epoch 1/2 : |█---------------------------------------| 3.70% [2/54 00:01<00:47 0.6573]
# Epoch 1/2 : |██--------------------------------------| 5.56% [3/54 00:02<00:37 0.7045]
# Epoch 1/2 : |███████---------------------------------| 18.52% [10/54 00:06<00:27 0.4840]
# Epoch 1/2 : |██--------------------------------------| 7.41% [4/54 00:02<00:32 0.6290]
# Epoch 1/2 : |████████--------------------------------| 20.37% [11/54 00:06<00:26 0.4616]
# Epoch 1/2 : |████████--------------------------------| 22.22% [12/54 00:07<00:25 0.4376]
# == Status ==
# Current time: 2023-01-17 18:23:08 (running for 00:00:19.25)
# Memory usage on this node: 22.2/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 48.0/48 CPUs, 2.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (3 PENDING, 2 RUNNING)
# +----------------+----------+---------------------+-----------------+
# | Trial name     | status   | loc                 | random stride   |
# |----------------+----------+---------------------+-----------------|
# | kits21_162_327 | RUNNING  | 192.168.0.63:563285 | False           |
# | kits21_162_329 | RUNNING  | 192.168.0.63:563461 | False           |
# | kits21_162_331 | PENDING  |                     | True            |
# | kits21_162_333 | PENDING  |                     | True            |
# | kits21_162_335 | PENDING  |                     | True            |
# +----------------+----------+---------------------+-----------------+
#
#
# Epoch 1/2 : |███-------------------------------------| 9.26% [5/54 00:03<00:35 0.5572]
# Epoch 1/2 : |████------------------------------------| 11.11% [6/54 00:03<00:31 0.5062]
# Epoch 1/2 : |█████████-------------------------------| 24.07% [13/54 00:08<00:25 0.4247]
# Epoch 1/2 : |█████-----------------------------------| 12.96% [7/54 00:04<00:29 0.4696]
# Epoch 1/2 : |██████████------------------------------| 25.93% [14/54 00:08<00:24 0.4170]
# Epoch 1/2 : |███████████-----------------------------| 27.78% [15/54 00:08<00:22 0.4022]
# Epoch 1/2 : |█████-----------------------------------| 14.81% [8/54 00:05<00:28 0.4300]
# Epoch 1/2 : |██████----------------------------------| 16.67% [9/54 00:05<00:27 0.3983]
# Epoch 1/2 : |███████████-----------------------------| 29.63% [16/54 00:09<00:23 0.3976]
# Epoch 1/2 : |███████---------------------------------| 18.52% [10/54 00:06<00:27 0.3716]
# Epoch 1/2 : |████████████----------------------------| 31.48% [17/54 00:10<00:22 0.3907]
# Epoch 1/2 : |████████--------------------------------| 20.37% [11/54 00:06<00:26 0.3822]
# Epoch 1/2 : |█████████████---------------------------| 33.33% [18/54 00:10<00:21 0.3780]
# Epoch 1/2 : |████████--------------------------------| 22.22% [12/54 00:07<00:24 0.3599]
# Epoch 1/2 : |██████████████--------------------------| 35.19% [19/54 00:11<00:20 0.3662]
# Epoch 1/2 : |██████████████--------------------------| 37.04% [20/54 00:11<00:19 0.3540]
# Epoch 1/2 : |█████████-------------------------------| 24.07% [13/54 00:07<00:24 0.3402]
# Epoch 1/2 : |███████████████-------------------------| 38.89% [21/54 00:11<00:18 0.3429]
# Epoch 1/2 : |██████████------------------------------| 25.93% [14/54 00:08<00:23 0.3279]
# Epoch 1/2 : |████████████████------------------------| 40.74% [22/54 00:12<00:18 0.3306]
# Epoch 1/2 : |███████████-----------------------------| 27.78% [15/54 00:08<00:22 0.3181]
# == Status ==
# Current time: 2023-01-17 18:23:13 (running for 00:00:24.25)
# Memory usage on this node: 22.2/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 48.0/48 CPUs, 2.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (3 PENDING, 2 RUNNING)
# +----------------+----------+---------------------+-----------------+
# | Trial name     | status   | loc                 | random stride   |
# |----------------+----------+---------------------+-----------------|
# | kits21_162_327 | RUNNING  | 192.168.0.63:563285 | False           |
# | kits21_162_329 | RUNNING  | 192.168.0.63:563461 | False           |
# | kits21_162_331 | PENDING  |                     | True            |
# | kits21_162_333 | PENDING  |                     | True            |
# | kits21_162_335 | PENDING  |                     | True            |
# +----------------+----------+---------------------+-----------------+
#
#
# Epoch 1/2 : |█████████████████-----------------------| 42.59% [23/54 00:12<00:17 0.3250]
# Epoch 1/2 : |███████████-----------------------------| 29.63% [16/54 00:09<00:22 0.3109]
# Epoch 1/2 : |█████████████████-----------------------| 44.44% [24/54 00:13<00:16 0.3125]
# Epoch 1/2 : |████████████----------------------------| 31.48% [17/54 00:09<00:21 0.2928]
# Epoch 1/2 : |██████████████████----------------------| 46.30% [25/54 00:13<00:16 0.3081]
# Epoch 1/2 : |█████████████---------------------------| 33.33% [18/54 00:10<00:20 0.3005]
# Epoch 1/2 : |███████████████████---------------------| 48.15% [26/54 00:14<00:15 0.2997]
# Epoch 1/2 : |████████████████████--------------------| 50.00% [27/54 00:14<00:14 0.2899]
# Epoch 1/2 : |████████████████████--------------------| 51.85% [28/54 00:15<00:13 0.2799]
# Epoch 1/2 : |██████████████--------------------------| 35.19% [19/54 00:11<00:20 0.2859]
# Epoch 1/2 : |█████████████████████-------------------| 53.70% [29/54 00:15<00:13 0.2678]
# Epoch 1/2 : |██████████████--------------------------| 37.04% [20/54 00:11<00:19 0.2746]
# Epoch 1/2 : |███████████████-------------------------| 38.89% [21/54 00:11<00:18 0.2622]
# Epoch 1/2 : |████████████████------------------------| 40.74% [22/54 00:12<00:17 0.2489]
# Epoch 1/2 : |██████████████████████------------------| 55.56% [30/54 00:16<00:13 0.2582]
# Epoch 1/2 : |██████████████████████------------------| 57.41% [31/54 00:16<00:12 0.2543]
# Epoch 1/2 : |███████████████████████-----------------| 59.26% [32/54 00:17<00:11 0.2470]
# Epoch 1/2 : |█████████████████-----------------------| 42.59% [23/54 00:13<00:17 0.2353]
# == Status ==
# Current time: 2023-01-17 18:23:18 (running for 00:00:29.25)
# Memory usage on this node: 22.3/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 48.0/48 CPUs, 2.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (3 PENDING, 2 RUNNING)
# +----------------+----------+---------------------+-----------------+
# | Trial name     | status   | loc                 | random stride   |
# |----------------+----------+---------------------+-----------------|
# | kits21_162_327 | RUNNING  | 192.168.0.63:563285 | False           |
# | kits21_162_329 | RUNNING  | 192.168.0.63:563461 | False           |
# | kits21_162_331 | PENDING  |                     | True            |
# | kits21_162_333 | PENDING  |                     | True            |
# | kits21_162_335 | PENDING  |                     | True            |
# +----------------+----------+---------------------+-----------------+
#
#
# Epoch 1/2 : |█████████████████-----------------------| 44.44% [24/54 00:13<00:17 0.2307]
# Epoch 1/2 : |██████████████████----------------------| 46.30% [25/54 00:14<00:16 0.2198]
# Epoch 1/2 : |████████████████████████----------------| 61.11% [33/54 00:18<00:11 0.2383]
# Epoch 1/2 : |███████████████████---------------------| 48.15% [26/54 00:14<00:15 0.2131]
# Epoch 1/2 : |█████████████████████████---------------| 62.96% [34/54 00:19<00:11 0.2325]
# Epoch 1/2 : |████████████████████--------------------| 50.00% [27/54 00:15<00:15 0.2070]
# Epoch 1/2 : |█████████████████████████---------------| 64.81% [35/54 00:19<00:10 0.2268]
# Epoch 1/2 : |████████████████████--------------------| 51.85% [28/54 00:16<00:14 0.2002]
# Epoch 1/2 : |██████████████████████████--------------| 66.67% [36/54 00:20<00:10 0.2321]
# Epoch 1/2 : |███████████████████████████-------------| 68.52% [37/54 00:20<00:09 0.2226]
# Epoch 1/2 : |█████████████████████-------------------| 53.70% [29/54 00:16<00:14 0.2106]
# Epoch 1/2 : |████████████████████████████------------| 70.37% [38/54 00:20<00:08 0.2237]
# Epoch 1/2 : |████████████████████████████------------| 72.22% [39/54 00:21<00:08 0.2236]
# Epoch 1/2 : |██████████████████████------------------| 55.56% [30/54 00:17<00:13 0.2050]
# Epoch 1/2 : |█████████████████████████████-----------| 74.07% [40/54 00:21<00:07 0.2168]
# Epoch 1/2 : |██████████████████████------------------| 57.41% [31/54 00:17<00:13 0.1975]
# Epoch 1/2 : |██████████████████████████████----------| 75.93% [41/54 00:22<00:06 0.2183]
# == Status ==
# Current time: 2023-01-17 18:23:23 (running for 00:00:34.26)
# Memory usage on this node: 22.3/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 48.0/48 CPUs, 2.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (3 PENDING, 2 RUNNING)
# +----------------+----------+---------------------+-----------------+
# | Trial name     | status   | loc                 | random stride   |
# |----------------+----------+---------------------+-----------------|
# | kits21_162_327 | RUNNING  | 192.168.0.63:563285 | False           |
# | kits21_162_329 | RUNNING  | 192.168.0.63:563461 | False           |
# | kits21_162_331 | PENDING  |                     | True            |
# | kits21_162_333 | PENDING  |                     | True            |
# | kits21_162_335 | PENDING  |                     | True            |
# +----------------+----------+---------------------+-----------------+
#
#
# Epoch 1/2 : |███████████████████████-----------------| 59.26% [32/54 00:18<00:12 0.1905]
# Epoch 1/2 : |███████████████████████████████---------| 77.78% [42/54 00:23<00:06 0.2115]
# Epoch 1/2 : |████████████████████████----------------| 61.11% [33/54 00:19<00:12 0.1867]
# Epoch 1/2 : |███████████████████████████████---------| 79.63% [43/54 00:23<00:06 0.2127]
# Epoch 1/2 : |█████████████████████████---------------| 62.96% [34/54 00:20<00:11 0.1834]
# Epoch 1/2 : |█████████████████████████---------------| 64.81% [35/54 00:20<00:11 0.1842]
# Epoch 1/2 : |██████████████████████████--------------| 66.67% [36/54 00:20<00:10 0.1763]
# Epoch 1/2 : |████████████████████████████████--------| 81.48% [44/54 00:24<00:05 0.2083]
# Epoch 1/2 : |███████████████████████████-------------| 68.52% [37/54 00:21<00:09 0.1688]
# Epoch 1/2 : |█████████████████████████████████-------| 83.33% [45/54 00:25<00:05 0.2055]
# Epoch 1/2 : |██████████████████████████████████------| 85.19% [46/54 00:26<00:04 0.2001]
# Epoch 1/2 : |████████████████████████████------------| 70.37% [38/54 00:22<00:09 0.1655]
# Epoch 1/2 : |██████████████████████████████████------| 87.04% [47/54 00:26<00:03 0.1965]
# Epoch 1/2 : |███████████████████████████████████-----| 88.89% [48/54 00:26<00:03 0.1911]
# Epoch 1/2 : |████████████████████████████------------| 72.22% [39/54 00:23<00:08 0.1675]
# Epoch 1/2 : |████████████████████████████████████----| 90.74% [49/54 00:27<00:02 0.1906]
# == Status ==
# Current time: 2023-01-17 18:23:28 (running for 00:00:39.26)
# Memory usage on this node: 22.2/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 48.0/48 CPUs, 2.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (3 PENDING, 2 RUNNING)
# +----------------+----------+---------------------+-----------------+
# | Trial name     | status   | loc                 | random stride   |
# |----------------+----------+---------------------+-----------------|
# | kits21_162_327 | RUNNING  | 192.168.0.63:563285 | False           |
# | kits21_162_329 | RUNNING  | 192.168.0.63:563461 | False           |
# | kits21_162_331 | PENDING  |                     | True            |
# | kits21_162_333 | PENDING  |                     | True            |
# | kits21_162_335 | PENDING  |                     | True            |
# +----------------+----------+---------------------+-----------------+
#
#
# Epoch 1/2 : |█████████████████████████████████████---| 92.59% [50/54 00:27<00:02 0.1849]
# Epoch 1/2 : |█████████████████████████████-----------| 74.07% [40/54 00:23<00:08 0.1643]
# Epoch 1/2 : |██████████████████████████████----------| 75.93% [41/54 00:24<00:07 0.1623]
# Epoch 1/2 : |█████████████████████████████████████---| 94.44% [51/54 00:28<00:01 0.1787]
# Epoch 1/2 : |██████████████████████████████████████--| 96.30% [52/54 00:28<00:01 0.1764]
# Epoch 1/2 : |███████████████████████████████---------| 77.78% [42/54 00:24<00:07 0.1604]
# Epoch 1/2 : |███████████████████████████████---------| 79.63% [43/54 00:25<00:06 0.1585]
# Epoch 1/2 : |███████████████████████████████████████-| 98.15% [53/54 00:29<00:00 0.1701]
# Epoch 1/2 : |----------------------------------------| 0.00% [0/14 00:00<?]
# Epoch 1/2 : |██--------------------------------------| 7.14% [1/14 00:00<00:01]
# Epoch 1/2 : |████████████████████████████████--------| 81.48% [44/54 00:26<00:05 0.1595]
# Epoch 1/2 : |█████-----------------------------------| 14.29% [2/14 00:00<00:01 0.1619]
# Epoch 1/2 : |████████--------------------------------| 21.43% [3/14 00:00<00:01 0.1619]
# Epoch 1/2 : |███████████-----------------------------| 28.57% [4/14 00:00<00:01 0.1619]
# Epoch 1/2 : |██████████████--------------------------| 35.71% [5/14 00:00<00:01 0.1619]
# Epoch 1/2 : |█████████████████-----------------------| 42.86% [6/14 00:00<00:01 0.1619]
# Epoch 1/2 : |█████████████████████████████████-------| 83.33% [45/54 00:26<00:05 0.1561]
# Epoch 1/2 : |████████████████████--------------------| 50.00% [7/14 00:00<00:00 0.1619]
# Epoch 1/2 : |██████████████████████------------------| 57.14% [8/14 00:01<00:00 0.1619]
# Epoch 1/2 : |█████████████████████████---------------| 64.29% [9/14 00:01<00:00 0.1619]
# Epoch 1/2 : |██████████████████████████████████------| 85.19% [46/54 00:27<00:04 0.1519]
# Epoch 1/2 : |████████████████████████████------------| 71.43% [10/14 00:01<00:00 0.1619]
# Epoch 1/2 : |███████████████████████████████---------| 78.57% [11/14 00:01<00:00 0.1619]
# Epoch 1/2 : |██████████████████████████████████------| 85.71% [12/14 00:01<00:00 0.1619]
# Epoch 1/2 : |█████████████████████████████████████---| 92.86% [13/14 00:01<00:00 0.1619]
# 0         0.161862    0.071763    00:31
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name    </th><th>date               </th><th>done  </th><th>episodes_total  </th><th>experiment_id                   </th><th>experiment_tag                                                                                                                                          </th><th>hostname  </th><th style="text-align: right;">  iterations_since_restore</th><th style="text-align: right;">     loss</th><th style="text-align: right;">  loss_ce_focal</th><th style="text-align: right;">  loss_dice</th><th style="text-align: right;">  loss_dice_label1</th><th style="text-align: right;">  loss_dice_label2</th><th style="text-align: right;">  loss_dice_label3</th><th>node_ip     </th><th style="text-align: right;">   pid</th><th style="text-align: right;">  time_since_restore</th><th style="text-align: right;">  time_this_iter_s</th><th style="text-align: right;">  time_total_s</th><th style="text-align: right;">  timestamp</th><th style="text-align: right;">  timesteps_since_restore</th><th>timesteps_total  </th><th style="text-align: right;">  training_iteration</th><th>trial_id   </th><th style="text-align: right;">  warmup_time</th></tr>
# </thead>
# <tbody>
# <tr><td>kits21_162_327</td><td>2023-01-17_18-24-10</td><td>True  </td><td>                </td><td>636c1f52c9f248a0b1a1eb74c8b368bb</td><td>0_0=0.8208,1=1.6127,1=0.1623,0=0.4023,1=1.5693,1=0.3327,0=-0.7508,1=0.7600,1=0.4159,stride_random=False,base_ch_opts=16,deep_supervision=False,lr=0.0035</td><td>zen       </td><td style="text-align: right;">                         2</td><td style="text-align: right;">0.117164 </td><td style="text-align: right;">       0.520817</td><td style="text-align: right;">  -0.286489</td><td style="text-align: right;">         -0.596494</td><td style="text-align: right;">         -0.224746</td><td style="text-align: right;">       -0.0382262 </td><td>192.168.0.63</td><td style="text-align: right;">563285</td><td style="text-align: right;">             77.1088</td><td style="text-align: right;">           37.2422</td><td style="text-align: right;">       77.1088</td><td style="text-align: right;"> 1673979850</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   2</td><td>f29df_00000</td><td style="text-align: right;">   0.00214434</td></tr>
# <tr><td>kits21_162_329</td><td>2023-01-17_18-24-14</td><td>True  </td><td>                </td><td>8517274fabd048a6915f99bd06a89fb9</td><td>1_0=0.9547,1=1.7595,1=0.2284,0=0.2711,1=1.7794,1=0.1492,0=-0.9756,1=0.7258,1=0.9663,stride_random=False,base_ch_opts=32,deep_supervision=False,lr=0.0100</td><td>zen       </td><td style="text-align: right;">                         2</td><td style="text-align: right;">0.127463 </td><td style="text-align: right;">       0.547977</td><td style="text-align: right;">  -0.293052</td><td style="text-align: right;">         -0.499109</td><td style="text-align: right;">         -0.346449</td><td style="text-align: right;">       -0.0335971 </td><td>192.168.0.63</td><td style="text-align: right;">563461</td><td style="text-align: right;">             77.3805</td><td style="text-align: right;">           35.307 </td><td style="text-align: right;">       77.3805</td><td style="text-align: right;"> 1673979854</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   2</td><td>f29df_00001</td><td style="text-align: right;">   0.00210381</td></tr>
# <tr><td>kits21_162_331</td><td>2023-01-17_18-25-27</td><td>True  </td><td>                </td><td>636c1f52c9f248a0b1a1eb74c8b368bb</td><td>2_0=0.6264,1=1.6404,1=0.8658,0=0.2935,1=1.6498,1=0.9770,0=-0.6378,1=0.6059,1=0.2484,stride_random=True,base_ch_opts=32,deep_supervision=True,lr=0.0025  </td><td>zen       </td><td style="text-align: right;">                         2</td><td style="text-align: right;">0.11596  </td><td style="text-align: right;">       0.529504</td><td style="text-align: right;">  -0.297584</td><td style="text-align: right;">         -0.60311 </td><td style="text-align: right;">         -0.281443</td><td style="text-align: right;">       -0.00819869</td><td>192.168.0.63</td><td style="text-align: right;">563285</td><td style="text-align: right;">             71.2425</td><td style="text-align: right;">           35.6964</td><td style="text-align: right;">       71.2425</td><td style="text-align: right;"> 1673979927</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   2</td><td>f29df_00002</td><td style="text-align: right;">   0.00214434</td></tr>
# <tr><td>kits21_162_333</td><td>2023-01-17_18-25-26</td><td>True  </td><td>                </td><td>8517274fabd048a6915f99bd06a89fb9</td><td>3_0=0.6329,1=1.6175,1=0.9620,0=0.3386,1=1.5884,1=0.6512,0=-0.6391,1=0.7441,1=0.5638,stride_random=True,base_ch_opts=32,deep_supervision=True,lr=0.0055  </td><td>zen       </td><td style="text-align: right;">                         2</td><td style="text-align: right;">0.0890995</td><td style="text-align: right;">       0.479782</td><td style="text-align: right;">  -0.301583</td><td style="text-align: right;">         -0.489953</td><td style="text-align: right;">         -0.377812</td><td style="text-align: right;">       -0.0369825 </td><td>192.168.0.63</td><td style="text-align: right;">563461</td><td style="text-align: right;">             66.4962</td><td style="text-align: right;">           32.9996</td><td style="text-align: right;">       66.4962</td><td style="text-align: right;"> 1673979926</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   2</td><td>f29df_00003</td><td style="text-align: right;">   0.00210381</td></tr>
# <tr><td>kits21_162_335</td><td>2023-01-17_18-26-45</td><td>True  </td><td>                </td><td>8517274fabd048a6915f99bd06a89fb9</td><td>4_0=0.9754,1=1.5360,1=0.7411,0=0.4758,1=1.6444,1=0.9664,0=-0.5670,1=0.7777,1=0.1080,stride_random=True,base_ch_opts=16,deep_supervision=True,lr=0.0025  </td><td>zen       </td><td style="text-align: right;">                         2</td><td style="text-align: right;">0.0722236</td><td style="text-align: right;">       0.474749</td><td style="text-align: right;">  -0.330302</td><td style="text-align: right;">         -0.644837</td><td style="text-align: right;">         -0.34016 </td><td style="text-align: right;">       -0.00590859</td><td>192.168.0.63</td><td style="text-align: right;">563461</td><td style="text-align: right;">             73.4169</td><td style="text-align: right;">           37.5028</td><td style="text-align: right;">       73.4169</td><td style="text-align: right;"> 1673980005</td><td style="text-align: right;">                        0</td><td>                 </td><td style="text-align: right;">                   2</td><td>f29df_00004</td><td style="text-align: right;">   0.00210381</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# (func pid=563285) Better model found at epoch 0 with valid_loss value: 0.07176317274570465.
# Epoch 1/2 : |██████████████████████████████████------| 87.04% [47/54 00:28<00:04 0.1470]
# (func pid=563285) /home/ub/programs/miniconda3/envs/ai/lib/python3.10/site-packages/neptune/new/attributes/atoms/string.py:54: NeptuneDeprecationWarning: The object you're logging will be implicitly cast to a string. We'll end support of this behavior in `neptune-client==1.0.0`. To log the object as a string, use `String(str(object))` instead.
# (func pid=563285)   value = StringVal(value)
# Epoch 1/2 : |███████████████████████████████████-----| 88.89% [48/54 00:29<00:03 0.1511]
# Epoch 1/2 : |████████████████████████████████████----| 90.74% [49/54 00:29<00:03 0.1491]
# Epoch 1/2 : |█████████████████████████████████████---| 92.59% [50/54 00:30<00:02 0.1457]
# Epoch 2/2 : |----------------------------------------| 0.00% [0/54 00:00<?]
# Epoch 1/2 : |█████████████████████████████████████---| 94.44% [51/54 00:31<00:01 0.1435]
# Epoch 1/2 : |██████████████████████████████████████--| 96.30% [52/54 00:31<00:01 0.1395]
# Epoch 2/2 : |----------------------------------------| 1.85% [1/54 00:01<00:53]
# Epoch 1/2 : |███████████████████████████████████████-| 98.15% [53/54 00:31<00:00 0.1359]
# Epoch 1/2 : |----------------------------------------| 0.00% [0/14 00:00<?]
# Epoch 1/2 : |██--------------------------------------| 7.14% [1/14 00:00<00:01]
# Epoch 1/2 : |█████-----------------------------------| 14.29% [2/14 00:00<00:01 0.1320]
# Epoch 2/2 : |█---------------------------------------| 3.70% [2/54 00:01<00:48 0.1581]
# Epoch 1/2 : |████████--------------------------------| 21.43% [3/14 00:00<00:01 0.1320]
# Epoch 1/2 : |███████████-----------------------------| 28.57% [4/14 00:00<00:01 0.1320]
# Epoch 1/2 : |██████████████--------------------------| 35.71% [5/14 00:00<00:01 0.1320]
# Epoch 2/2 : |██--------------------------------------| 5.56% [3/54 00:02<00:38 0.1545]
# Epoch 1/2 : |█████████████████-----------------------| 42.86% [6/14 00:00<00:01 0.1320]
# Epoch 1/2 : |████████████████████--------------------| 50.00% [7/14 00:00<00:00 0.1320]
# Epoch 1/2 : |██████████████████████------------------| 57.14% [8/14 00:01<00:00 0.1320]
# == Status ==
# Current time: 2023-01-17 18:23:38 (running for 00:00:49.12)
# Memory usage on this node: 22.1/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 48.0/48 CPUs, 2.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (3 PENDING, 2 RUNNING)
# +----------------+----------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
# | Trial name     | status   | loc                 | random stride   |   training_iteration | loss_ce_focal   | loss_dice_label1   | loss_dice_label2   | loss_dice_label3   |
# |----------------+----------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------|
# | kits21_162_327 | RUNNING  | 192.168.0.63:563285 | False           |                    1 | tensor(0.5716)  | tensor(-0.5052)    | tensor(-0.1820)    | tensor(-0.0032)    |
# | kits21_162_329 | RUNNING  | 192.168.0.63:563461 | False           |                      |                 |                    |                    |                    |
# | kits21_162_331 | PENDING  |                     | True            |                      |                 |                    |                    |                    |
# | kits21_162_333 | PENDING  |                     | True            |                      |                 |                    |                    |                    |
# | kits21_162_335 | PENDING  |                     | True            |                      |                 |                    |                    |                    |
# +----------------+----------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
#
#
# Epoch 2/2 : |██--------------------------------------| 7.41% [4/54 00:02<00:33 0.1517]
# Epoch 1/2 : |█████████████████████████---------------| 64.29% [9/14 00:01<00:00 0.1320]
# Epoch 1/2 : |████████████████████████████------------| 71.43% [10/14 00:01<00:00 0.1320]
# Epoch 1/2 : |███████████████████████████████---------| 78.57% [11/14 00:01<00:00 0.1320]
# Epoch 1/2 : |██████████████████████████████████------| 85.71% [12/14 00:01<00:00 0.1320]
# Epoch 1/2 : |█████████████████████████████████████---| 92.86% [13/14 00:01<00:00 0.1320]
# 0         0.132049    0.064211    00:34
# Epoch 2/2 : |███-------------------------------------| 9.26% [5/54 00:03<00:33 0.1466]
# (func pid=563461) Better model found at epoch 0 with valid_loss value: 0.0642114132642746.
# Epoch 2/2 : |████------------------------------------| 11.11% [6/54 00:03<00:30 0.1426]
# (func pid=563461) /home/ub/programs/miniconda3/envs/ai/lib/python3.10/site-packages/neptune/new/attributes/atoms/string.py:54: NeptuneDeprecationWarning: The object you're logging will be implicitly cast to a string. We'll end support of this behavior in `neptune-client==1.0.0`. To log the object as a string, use `String(str(object))` instead.
# (func pid=563461)   value = StringVal(value)
# Epoch 2/2 : |█████-----------------------------------| 12.96% [7/54 00:04<00:31 0.1376]
# Epoch 2/2 : |█████-----------------------------------| 14.81% [8/54 00:05<00:32 0.1340]
# Epoch 2/2 : |██████----------------------------------| 16.67% [9/54 00:06<00:30 0.1311]
# Epoch 2/2 : |----------------------------------------| 0.00% [0/54 00:00<?]
# Epoch 2/2 : |███████---------------------------------| 18.52% [10/54 00:06<00:28 0.1259]
# Epoch 2/2 : |----------------------------------------| 1.85% [1/54 00:00<00:20]
# Epoch 2/2 : |████████--------------------------------| 20.37% [11/54 00:07<00:28 0.1214]
# Epoch 2/2 : |█---------------------------------------| 3.70% [2/54 00:01<00:34 0.1288]
# Epoch 2/2 : |████████--------------------------------| 22.22% [12/54 00:07<00:26 0.1188]
# Epoch 2/2 : |█████████-------------------------------| 24.07% [13/54 00:08<00:25 0.1144]
# Epoch 2/2 : |██--------------------------------------| 5.56% [3/54 00:02<00:35 0.1316]
# Epoch 2/2 : |██████████------------------------------| 25.93% [14/54 00:08<00:24 0.1102]
# == Status ==
# Current time: 2023-01-17 18:23:44 (running for 00:00:55.23)
# Memory usage on this node: 22.3/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 48.0/48 CPUs, 2.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (3 PENDING, 2 RUNNING)
# +----------------+----------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
# | Trial name     | status   | loc                 | random stride   |   training_iteration | loss_ce_focal   | loss_dice_label1   | loss_dice_label2   | loss_dice_label3   |
# |----------------+----------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------|
# | kits21_162_327 | RUNNING  | 192.168.0.63:563285 | False           |                    1 | tensor(0.5716)  | tensor(-0.5052)    | tensor(-0.1820)    | tensor(-0.0032)    |
# | kits21_162_329 | RUNNING  | 192.168.0.63:563461 | False           |                    1 | tensor(0.5380)  | tensor(-0.4784)    | tensor(-0.2736)    | tensor(-0.0025)    |
# | kits21_162_331 | PENDING  |                     | True            |                      |                 |                    |                    |                    |
# | kits21_162_333 | PENDING  |                     | True            |                      |                 |                    |                    |                    |
# | kits21_162_335 | PENDING  |                     | True            |                      |                 |                    |                    |                    |
# +----------------+----------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
#
#
# Epoch 2/2 : |███████████-----------------------------| 27.78% [15/54 00:08<00:23 0.1073]
# Epoch 2/2 : |██--------------------------------------| 7.41% [4/54 00:02<00:36 0.1297]
# Epoch 2/2 : |███████████-----------------------------| 29.63% [16/54 00:09<00:22 0.1059]
# Epoch 2/2 : |███-------------------------------------| 9.26% [5/54 00:03<00:38 0.1252]
# Epoch 2/2 : |████████████----------------------------| 31.48% [17/54 00:10<00:22 0.1029]
# Epoch 2/2 : |████------------------------------------| 11.11% [6/54 00:04<00:34 0.1218]
# Epoch 2/2 : |█████████████---------------------------| 33.33% [18/54 00:10<00:21 0.1051]
# Epoch 2/2 : |█████-----------------------------------| 12.96% [7/54 00:04<00:31 0.1180]
# Epoch 2/2 : |██████████████--------------------------| 35.19% [19/54 00:11<00:20 0.1053]
# Epoch 2/2 : |██████████████--------------------------| 37.04% [20/54 00:11<00:19 0.1019]
# Epoch 2/2 : |███████████████-------------------------| 38.89% [21/54 00:12<00:19 0.0986]
# Epoch 2/2 : |█████-----------------------------------| 14.81% [8/54 00:05<00:33 0.1155]
# Epoch 2/2 : |██████----------------------------------| 16.67% [9/54 00:06<00:30 0.1185]
# Epoch 2/2 : |████████████████------------------------| 40.74% [22/54 00:12<00:18 0.0963]
# Epoch 2/2 : |█████████████████-----------------------| 42.59% [23/54 00:13<00:17 0.0956]
# Epoch 2/2 : |███████---------------------------------| 18.52% [10/54 00:07<00:32 0.1184]
# == Status ==
# Current time: 2023-01-17 18:23:49 (running for 00:01:00.24)
# Memory usage on this node: 22.4/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 48.0/48 CPUs, 2.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (3 PENDING, 2 RUNNING)
# +----------------+----------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
# | Trial name     | status   | loc                 | random stride   |   training_iteration | loss_ce_focal   | loss_dice_label1   | loss_dice_label2   | loss_dice_label3   |
# |----------------+----------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------|
# | kits21_162_327 | RUNNING  | 192.168.0.63:563285 | False           |                    1 | tensor(0.5716)  | tensor(-0.5052)    | tensor(-0.1820)    | tensor(-0.0032)    |
# | kits21_162_329 | RUNNING  | 192.168.0.63:563461 | False           |                    1 | tensor(0.5380)  | tensor(-0.4784)    | tensor(-0.2736)    | tensor(-0.0025)    |
# | kits21_162_331 | PENDING  |                     | True            |                      |                 |                    |                    |                    |
# | kits21_162_333 | PENDING  |                     | True            |                      |                 |                    |                    |                    |
# | kits21_162_335 | PENDING  |                     | True            |                      |                 |                    |                    |                    |
# +----------------+----------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
#
#
# Epoch 2/2 : |████████--------------------------------| 20.37% [11/54 00:07<00:29 0.1253]
# Epoch 2/2 : |█████████████████-----------------------| 44.44% [24/54 00:14<00:17 0.0926]
# Epoch 2/2 : |████████--------------------------------| 22.22% [12/54 00:08<00:28 0.1218]
# Epoch 2/2 : |██████████████████----------------------| 46.30% [25/54 00:14<00:16 0.0948]
# Epoch 2/2 : |█████████-------------------------------| 24.07% [13/54 00:08<00:26 0.1178]
# Epoch 2/2 : |██████████------------------------------| 25.93% [14/54 00:08<00:25 0.1170]
# Epoch 2/2 : |███████████-----------------------------| 27.78% [15/54 00:09<00:23 0.1140]
# Epoch 2/2 : |███████████████████---------------------| 48.15% [26/54 00:15<00:16 0.0919]
# Epoch 2/2 : |████████████████████--------------------| 50.00% [27/54 00:16<00:16 0.0930]
# Epoch 2/2 : |███████████-----------------------------| 29.63% [16/54 00:10<00:24 0.1118]
# Epoch 2/2 : |████████████████████--------------------| 51.85% [28/54 00:16<00:15 0.0905]
# Epoch 2/2 : |████████████----------------------------| 31.48% [17/54 00:10<00:23 0.1110]
# Epoch 2/2 : |█████████████████████-------------------| 53.70% [29/54 00:17<00:14 0.0896]
# Epoch 2/2 : |██████████████████████------------------| 55.56% [30/54 00:17<00:14 0.0898]
# Epoch 2/2 : |█████████████---------------------------| 33.33% [18/54 00:11<00:23 0.1095]
# Epoch 2/2 : |██████████████████████------------------| 57.41% [31/54 00:18<00:13 0.0897]
# == Status ==
# Current time: 2023-01-17 18:23:54 (running for 00:01:05.25)
# Memory usage on this node: 22.3/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 48.0/48 CPUs, 2.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (3 PENDING, 2 RUNNING)
# +----------------+----------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
# | Trial name     | status   | loc                 | random stride   |   training_iteration | loss_ce_focal   | loss_dice_label1   | loss_dice_label2   | loss_dice_label3   |
# |----------------+----------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------|
# | kits21_162_327 | RUNNING  | 192.168.0.63:563285 | False           |                    1 | tensor(0.5716)  | tensor(-0.5052)    | tensor(-0.1820)    | tensor(-0.0032)    |
# | kits21_162_329 | RUNNING  | 192.168.0.63:563461 | False           |                    1 | tensor(0.5380)  | tensor(-0.4784)    | tensor(-0.2736)    | tensor(-0.0025)    |
# | kits21_162_331 | PENDING  |                     | True            |                      |                 |                    |                    |                    |
# | kits21_162_333 | PENDING  |                     | True            |                      |                 |                    |                    |                    |
# | kits21_162_335 | PENDING  |                     | True            |                      |                 |                    |                    |                    |
# +----------------+----------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
#
#
# Epoch 2/2 : |██████████████--------------------------| 35.19% [19/54 00:12<00:22 0.1062]
# Epoch 2/2 : |██████████████--------------------------| 37.04% [20/54 00:12<00:21 0.1043]
# Epoch 2/2 : |███████████████████████-----------------| 59.26% [32/54 00:19<00:13 0.0910]
# Epoch 2/2 : |███████████████-------------------------| 38.89% [21/54 00:13<00:20 0.1009]
# Epoch 2/2 : |████████████████------------------------| 40.74% [22/54 00:13<00:20 0.0991]
# Epoch 2/2 : |████████████████████████----------------| 61.11% [33/54 00:20<00:12 0.0883]
# Epoch 2/2 : |█████████████████-----------------------| 42.59% [23/54 00:14<00:19 0.0987]
# Epoch 2/2 : |█████████████████████████---------------| 62.96% [34/54 00:21<00:12 0.0942]
# Epoch 2/2 : |█████████████████-----------------------| 44.44% [24/54 00:14<00:18 0.0969]
# Epoch 2/2 : |██████████████████----------------------| 46.30% [25/54 00:15<00:17 0.0969]
# Epoch 2/2 : |█████████████████████████---------------| 64.81% [35/54 00:21<00:11 0.0971]
# Epoch 2/2 : |███████████████████---------------------| 48.15% [26/54 00:16<00:17 0.0945]
# Epoch 2/2 : |████████████████████--------------------| 50.00% [27/54 00:16<00:16 0.0934]
# Epoch 2/2 : |██████████████████████████--------------| 66.67% [36/54 00:22<00:11 0.0970]
# Epoch 2/2 : |████████████████████--------------------| 51.85% [28/54 00:16<00:15 0.0949]
# Epoch 2/2 : |███████████████████████████-------------| 68.52% [37/54 00:23<00:10 0.0954]
# Epoch 2/2 : |█████████████████████-------------------| 53.70% [29/54 00:17<00:14 0.0919]
# Epoch 2/2 : |████████████████████████████------------| 70.37% [38/54 00:23<00:09 0.0928]
# == Status ==
# Current time: 2023-01-17 18:23:59 (running for 00:01:10.25)
# Memory usage on this node: 22.3/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 48.0/48 CPUs, 2.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (3 PENDING, 2 RUNNING)
# +----------------+----------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
# | Trial name     | status   | loc                 | random stride   |   training_iteration | loss_ce_focal   | loss_dice_label1   | loss_dice_label2   | loss_dice_label3   |
# |----------------+----------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------|
# | kits21_162_327 | RUNNING  | 192.168.0.63:563285 | False           |                    1 | tensor(0.5716)  | tensor(-0.5052)    | tensor(-0.1820)    | tensor(-0.0032)    |
# | kits21_162_329 | RUNNING  | 192.168.0.63:563461 | False           |                    1 | tensor(0.5380)  | tensor(-0.4784)    | tensor(-0.2736)    | tensor(-0.0025)    |
# ...
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 24.0/48 CPUs, 1.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
# | Trial name     | status     | loc                 | random stride   |   training_iteration | loss_ce_focal   | loss_dice_label1   | loss_dice_label2   | loss_dice_label3   |
# |----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------|
# | kits21_162_335 | RUNNING    | 192.168.0.63:563461 | True            |                    1 | tensor(0.5120)  | tensor(-0.5689)    | tensor(-0.2896)    | tensor(-0.0019)    |
# | kits21_162_327 | TERMINATED | 192.168.0.63:563285 | False           |                    2 | tensor(0.5208)  | tensor(-0.5965)    | tensor(-0.2247)    | tensor(-0.0382)    |
# | kits21_162_329 | TERMINATED | 192.168.0.63:563461 | False           |                    2 | tensor(0.5480)  | tensor(-0.4991)    | tensor(-0.3464)    | tensor(-0.0336)    |
# | kits21_162_331 | TERMINATED | 192.168.0.63:563285 | True            |                    2 | tensor(0.5295)  | tensor(-0.6031)    | tensor(-0.2814)    | tensor(-0.0082)    |
# | kits21_162_333 | TERMINATED | 192.168.0.63:563461 | True            |                    2 | tensor(0.4798)  | tensor(-0.4900)    | tensor(-0.3778)    | tensor(-0.0370)    |
# +----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
#
#
# Epoch 2/2 : |████████████████████--------------------| 51.85% [28/54 00:18<00:17 0.0829]
# Epoch 2/2 : |█████████████████████-------------------| 53.70% [29/54 00:19<00:16 0.0801]
# Epoch 2/2 : |██████████████████████------------------| 55.56% [30/54 00:20<00:16 0.0781]
# Epoch 2/2 : |██████████████████████------------------| 57.41% [31/54 00:20<00:15 0.0754]
# Epoch 2/2 : |███████████████████████-----------------| 59.26% [32/54 00:21<00:14 0.0721]
# Epoch 2/2 : |████████████████████████----------------| 61.11% [33/54 00:22<00:14 0.0709]
# == Status ==
# Current time: 2023-01-17 18:26:32 (running for 00:03:43.60)
# Memory usage on this node: 23.0/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 24.0/48 CPUs, 1.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
# | Trial name     | status     | loc                 | random stride   |   training_iteration | loss_ce_focal   | loss_dice_label1   | loss_dice_label2   | loss_dice_label3   |
# |----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------|
# | kits21_162_335 | RUNNING    | 192.168.0.63:563461 | True            |                    1 | tensor(0.5120)  | tensor(-0.5689)    | tensor(-0.2896)    | tensor(-0.0019)    |
# | kits21_162_327 | TERMINATED | 192.168.0.63:563285 | False           |                    2 | tensor(0.5208)  | tensor(-0.5965)    | tensor(-0.2247)    | tensor(-0.0382)    |
# | kits21_162_329 | TERMINATED | 192.168.0.63:563461 | False           |                    2 | tensor(0.5480)  | tensor(-0.4991)    | tensor(-0.3464)    | tensor(-0.0336)    |
# | kits21_162_331 | TERMINATED | 192.168.0.63:563285 | True            |                    2 | tensor(0.5295)  | tensor(-0.6031)    | tensor(-0.2814)    | tensor(-0.0082)    |
# | kits21_162_333 | TERMINATED | 192.168.0.63:563461 | True            |                    2 | tensor(0.4798)  | tensor(-0.4900)    | tensor(-0.3778)    | tensor(-0.0370)    |
# +----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
#
#
# Epoch 2/2 : |█████████████████████████---------------| 62.96% [34/54 00:22<00:13 0.0687]
# Epoch 2/2 : |█████████████████████████---------------| 64.81% [35/54 00:23<00:12 0.0672]
# Epoch 2/2 : |██████████████████████████--------------| 66.67% [36/54 00:23<00:11 0.0639]
# Epoch 2/2 : |███████████████████████████-------------| 68.52% [37/54 00:23<00:11 0.0617]
# Epoch 2/2 : |████████████████████████████------------| 70.37% [38/54 00:24<00:10 0.0583]
# Epoch 2/2 : |████████████████████████████------------| 72.22% [39/54 00:24<00:09 0.0567]
# Epoch 2/2 : |█████████████████████████████-----------| 74.07% [40/54 00:25<00:08 0.0546]
# Epoch 2/2 : |██████████████████████████████----------| 75.93% [41/54 00:25<00:08 0.0543]
# Epoch 2/2 : |███████████████████████████████---------| 77.78% [42/54 00:25<00:07 0.0547]
# Epoch 2/2 : |███████████████████████████████---------| 79.63% [43/54 00:26<00:06 0.0530]
# Epoch 2/2 : |████████████████████████████████--------| 81.48% [44/54 00:27<00:06 0.0523]
# == Status ==
# Current time: 2023-01-17 18:26:37 (running for 00:03:48.60)
# Memory usage on this node: 22.8/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 24.0/48 CPUs, 1.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
# | Trial name     | status     | loc                 | random stride   |   training_iteration | loss_ce_focal   | loss_dice_label1   | loss_dice_label2   | loss_dice_label3   |
# |----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------|
# | kits21_162_335 | RUNNING    | 192.168.0.63:563461 | True            |                    1 | tensor(0.5120)  | tensor(-0.5689)    | tensor(-0.2896)    | tensor(-0.0019)    |
# | kits21_162_327 | TERMINATED | 192.168.0.63:563285 | False           |                    2 | tensor(0.5208)  | tensor(-0.5965)    | tensor(-0.2247)    | tensor(-0.0382)    |
# | kits21_162_329 | TERMINATED | 192.168.0.63:563461 | False           |                    2 | tensor(0.5480)  | tensor(-0.4991)    | tensor(-0.3464)    | tensor(-0.0336)    |
# | kits21_162_331 | TERMINATED | 192.168.0.63:563285 | True            |                    2 | tensor(0.5295)  | tensor(-0.6031)    | tensor(-0.2814)    | tensor(-0.0082)    |
# | kits21_162_333 | TERMINATED | 192.168.0.63:563461 | True            |                    2 | tensor(0.4798)  | tensor(-0.4900)    | tensor(-0.3778)    | tensor(-0.0370)    |
# +----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
#
#
# Epoch 2/2 : |█████████████████████████████████-------| 83.33% [45/54 00:27<00:05 0.0496]
# Epoch 2/2 : |██████████████████████████████████------| 85.19% [46/54 00:28<00:04 0.0498]
# Epoch 2/2 : |██████████████████████████████████------| 87.04% [47/54 00:28<00:04 0.0473]
# Epoch 2/2 : |███████████████████████████████████-----| 88.89% [48/54 00:29<00:03 0.0444]
# Epoch 2/2 : |████████████████████████████████████----| 90.74% [49/54 00:29<00:03 0.0425]
# Epoch 2/2 : |█████████████████████████████████████---| 92.59% [50/54 00:30<00:02 0.0406]
# Epoch 2/2 : |█████████████████████████████████████---| 94.44% [51/54 00:31<00:01 0.0426]
# Epoch 2/2 : |██████████████████████████████████████--| 96.30% [52/54 00:32<00:01 0.0401]
# Epoch 2/2 : |███████████████████████████████████████-| 98.15% [53/54 00:32<00:00 0.0380]
# == Status ==
# Current time: 2023-01-17 18:26:42 (running for 00:03:53.61)
# Memory usage on this node: 22.9/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 24.0/48 CPUs, 1.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
# | Trial name     | status     | loc                 | random stride   |   training_iteration | loss_ce_focal   | loss_dice_label1   | loss_dice_label2   | loss_dice_label3   |
# |----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------|
# | kits21_162_335 | RUNNING    | 192.168.0.63:563461 | True            |                    1 | tensor(0.5120)  | tensor(-0.5689)    | tensor(-0.2896)    | tensor(-0.0019)    |
# | kits21_162_327 | TERMINATED | 192.168.0.63:563285 | False           |                    2 | tensor(0.5208)  | tensor(-0.5965)    | tensor(-0.2247)    | tensor(-0.0382)    |
# | kits21_162_329 | TERMINATED | 192.168.0.63:563461 | False           |                    2 | tensor(0.5480)  | tensor(-0.4991)    | tensor(-0.3464)    | tensor(-0.0336)    |
# | kits21_162_331 | TERMINATED | 192.168.0.63:563285 | True            |                    2 | tensor(0.5295)  | tensor(-0.6031)    | tensor(-0.2814)    | tensor(-0.0082)    |
# | kits21_162_333 | TERMINATED | 192.168.0.63:563461 | True            |                    2 | tensor(0.4798)  | tensor(-0.4900)    | tensor(-0.3778)    | tensor(-0.0370)    |
# +----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
#
#
# Epoch 2/2 : |----------------------------------------| 0.00% [0/14 00:00<?]
# Epoch 2/2 : |██--------------------------------------| 7.14% [1/14 00:00<00:01]
# Epoch 2/2 : |█████-----------------------------------| 14.29% [2/14 00:00<00:01 0.0404]
# Epoch 2/2 : |████████--------------------------------| 21.43% [3/14 00:00<00:01 0.0404]
# Epoch 2/2 : |███████████-----------------------------| 28.57% [4/14 00:00<00:01 0.0404]
# Epoch 2/2 : |██████████████--------------------------| 35.71% [5/14 00:00<00:01 0.0404]
# Epoch 2/2 : |█████████████████-----------------------| 42.86% [6/14 00:00<00:01 0.0404]
# Epoch 2/2 : |████████████████████--------------------| 50.00% [7/14 00:00<00:00 0.0404]
# Epoch 2/2 : |██████████████████████------------------| 57.14% [8/14 00:01<00:00 0.0404]
# Epoch 2/2 : |█████████████████████████---------------| 64.29% [9/14 00:01<00:00 0.0404]
# Epoch 2/2 : |████████████████████████████------------| 71.43% [10/14 00:01<00:00 0.0404]
# Epoch 2/2 : |███████████████████████████████---------| 78.57% [11/14 00:01<00:00 0.0404]
# Epoch 2/2 : |██████████████████████████████████------| 85.71% [12/14 00:01<00:00 0.0404]
# 1         0.040404    -0.015207   00:35
# (func pid=563461) Better model found at epoch 1 with valid_loss value: -0.015206713229417801.
# (func pid=563461) Shutting down background jobs, please wait a moment...
# (func pid=563461) Done!
# (func pid=563461) Waiting for the remaining 30 operations to synchronize with Neptune. Do not kill this process.
# == Status ==
# Current time: 2023-01-17 18:26:50 (running for 00:04:01.08)
# Memory usage on this node: 22.8/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 24.0/48 CPUs, 1.0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (1 RUNNING, 4 TERMINATED)
# +----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
# | Trial name     | status     | loc                 | random stride   |   training_iteration | loss_ce_focal   | loss_dice_label1   | loss_dice_label2   | loss_dice_label3   |
# |----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------|
# | kits21_162_335 | RUNNING    | 192.168.0.63:563461 | True            |                    2 | tensor(0.4747)  | tensor(-0.6448)    | tensor(-0.3402)    | tensor(-0.0059)    |
# | kits21_162_327 | TERMINATED | 192.168.0.63:563285 | False           |                    2 | tensor(0.5208)  | tensor(-0.5965)    | tensor(-0.2247)    | tensor(-0.0382)    |
# | kits21_162_329 | TERMINATED | 192.168.0.63:563461 | False           |                    2 | tensor(0.5480)  | tensor(-0.4991)    | tensor(-0.3464)    | tensor(-0.0336)    |
# | kits21_162_331 | TERMINATED | 192.168.0.63:563285 | True            |                    2 | tensor(0.5295)  | tensor(-0.6031)    | tensor(-0.2814)    | tensor(-0.0082)    |
# | kits21_162_333 | TERMINATED | 192.168.0.63:563461 | True            |                    2 | tensor(0.4798)  | tensor(-0.4900)    | tensor(-0.3778)    | tensor(-0.0370)    |
# +----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
#
#
# (func pid=563461) All 30 operations synced, thanks for waiting!
# (func pid=563461) Explore the metadata in the Neptune app:
# (func pid=563461) https://app.neptune.ai/drusmanbashir/KiTS19/e/KITS-2391
# == Status ==
# Current time: 2023-01-17 18:26:51 (running for 00:04:01.91)
# Memory usage on this node: 22.8/62.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 2.000: None | Iter 1.000: None
# Resources requested: 0/48 CPUs, 0/2 GPUs, 0.0/31.51 GiB heap, 0.0/15.76 GiB objects (0.0/1.0 accelerator_type:G)
# Result logdir: /s/checkpoints/kits21/kits21_162
# Number of trials: 5/5 (5 TERMINATED)
# +----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
# | Trial name     | status     | loc                 | random stride   |   training_iteration | loss_ce_focal   | loss_dice_label1   | loss_dice_label2   | loss_dice_label3   |
# |----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------|
# | kits21_162_327 | TERMINATED | 192.168.0.63:563285 | False           |                    2 | tensor(0.5208)  | tensor(-0.5965)    | tensor(-0.2247)    | tensor(-0.0382)    |
# | kits21_162_329 | TERMINATED | 192.168.0.63:563461 | False           |                    2 | tensor(0.5480)  | tensor(-0.4991)    | tensor(-0.3464)    | tensor(-0.0336)    |
# | kits21_162_331 | TERMINATED | 192.168.0.63:563285 | True            |                    2 | tensor(0.5295)  | tensor(-0.6031)    | tensor(-0.2814)    | tensor(-0.0082)    |
# | kits21_162_333 | TERMINATED | 192.168.0.63:563461 | True            |                    2 | tensor(0.4798)  | tensor(-0.4900)    | tensor(-0.3778)    | tensor(-0.0370)    |
# | kits21_162_335 | TERMINATED | 192.168.0.63:563461 | True            |                    2 | tensor(0.4747)  | tensor(-0.6448)    | tensor(-0.3402)    | tensor(-0.0059)    |
# +----------------+------------+---------------------+-----------------+----------------------+-----------------+--------------------+--------------------+--------------------+
# 2023-01-17 18:26:51,445	INFO tune.py:762 -- Total run time: 242.13 seconds (241.91 seconds for the tuning loop).

# %% [markdown]
# # Examining the results:
# ### Check out https://docs.ray.io/en/latest/tune/examples/tune_analyze_results.html for more info.

# %%
results

# %%
num_results = len(results)
print("Number of results:", num_results)
# Out:
# Number of results: 5

# %%
# Iterate over results
for i, result in enumerate(results):
    if result.error:
        print(f"Trial #{i} had an error:", result.error)
        continue

    print(
        f"Trial #{i} finished successfully with a mean accuracy metric of:",
        result.metrics["loss_dice_label2"]   # tumour dice
    )
# Out:
# Trial #0 finished successfully with a mean accuracy metric of: tensor(-0.2247)
# Trial #1 finished successfully with a mean accuracy metric of: tensor(-0.3464)
# Trial #2 finished successfully with a mean accuracy metric of: tensor(-0.2814)
# Trial #3 finished successfully with a mean accuracy metric of: tensor(-0.3778)
# Trial #4 finished successfully with a mean accuracy metric of: tensor(-0.3402)
